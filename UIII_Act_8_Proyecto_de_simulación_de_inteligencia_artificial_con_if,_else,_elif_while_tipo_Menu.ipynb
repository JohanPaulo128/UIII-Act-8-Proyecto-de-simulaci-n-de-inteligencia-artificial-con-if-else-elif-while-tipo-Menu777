# %% [markdown]
# <a href="https://colab.research.google.com/github/JohanPaulo128/UIII-Act-8-Proyecto-de-simulaci-n-de-inteligencia-artificial-con-if-else-elif-while-tipo-Menu777/blob/main/UIII_Act_8_Proyecto_de_simulaci%C3%B3n_de_inteligencia_artificial_con_if%2C_else%2C_elif_while_tipo_Menu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Johan Paulo Aros Reveles Nl=04 Fecha 21/Mayo/2026
# ### Escritor y libro

# %%
opcion = ""
while opcion != "4":
    print("\n--- MENÚ ESCRITOR AI ---")
    print("1. Elegir Protagonista")
    print("2. Definir Escenario")
    print("3. Generar Trama")
    print("4. Salir")
    opcion = input("Selecciona una opción (1-4): ")

    if opcion == "1":
        print("AI: Sugiero un detective robot o una astronauta perdida.")
    elif opcion == "2":
        print("AI: El escenario podría ser Marte o una biblioteca antigua.")
    elif opcion == "3":
        print("AI: ¡Trama generada! Un misterio en el espacio profundo.")
    elif opcion != "4":
        print("Opción no válida, intenta de nuevo.")
# Out:
# --- MENÚ ESCRITOR AI ---
# 1. Elegir Protagonista
# 2. Definir Escenario
# 3. Generar Trama
# 4. Salir
# Selecciona una opción (1-4): 1
# AI: Sugiero un detective robot o una astronauta perdida.
#
# --- MENÚ ESCRITOR AI ---
# 1. Elegir Protagonista
# 2. Definir Escenario
# 3. Generar Trama
# 4. Salir
# Selecciona una opción (1-4): 2
# AI: El escenario podría ser Marte o una biblioteca antigua.
#
# --- MENÚ ESCRITOR AI ---
# 1. Elegir Protagonista
# 2. Definir Escenario
# 3. Generar Trama
# 4. Salir
# Selecciona una opción (1-4): 3
# AI: ¡Trama generada! Un misterio en el espacio profundo.
#
# --- MENÚ ESCRITOR AI ---
# 1. Elegir Protagonista
# 2. Definir Escenario
# 3. Generar Trama
# 4. Salir
# Selecciona una opción (1-4): 4

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/JohanPaulo128/UIII-Act-8-Proyecto-de-simulaci-n-de-inteligencia-artificial-con-if-else-elif-while-tipo-Menu777/refs/heads/main/InfoEscritor.png)
#
# ![texto del vínculo](https://raw.githubusercontent.com/JohanPaulo128/UIII-Act-7-Proyecto-de-simulaci-n-de-inteligencia-artificial-con-if-else-elif-while-tipo-Menu-9999/refs/heads/main/infolibrotipomenu.png)
